# %% [markdown]
# ![week06-1.png](data:image/png;base64,...)

# %% [markdown]
# ```java
# //week06-1
# // week06-1 好玩的程式設計
# // File-Preference偏好設定, 字型放大, 接續上週的 week05-5
# int[][]b=new int[10][16];
# void setup() {
#   size(800, 500);
# }
#
# void draw() {
#   background(255);
#   for (int i=0; i<10; i++) {
#     for (int j=0; j<16; j++) {
#       if(b[i][j]==1)fill(#F5CBFF);
#       else fill(255);
#       rect( j*50, i*50, 50, 50);
#     }
#   }
# }
# void mousePressed(){
#   int i=mouseY /50,j=mouseX /50;
#   b[i][j]=1;
# }
# ```

# %% [markdown]
# ![week06-2.png](data:image/png;base64,...)

# %% [markdown]
# ```java
# // week06-2 好玩的程式設計
# // Ctrl-N 開新視窗, 貼上剛剛的 week06-1
# // 接續上週的 week01-1
# int [][] b = new int[10][16]; // Java 的 2D陣列
# void setup() {
#   size(800, 500); // 視窗大小 800 x 500
# }
# void draw() {
#   background(255); // 背景白色
#   for (int i=0; i<10; i++) { // 左手 i 的 for(迴圈) 對應 y 座標
#     for (int j=0; j<16; j++) { // 右手 j 的 for(迴圈) 對應 x 座標
#       if (b[i][j] > 0) {
#         fill(#F5CBFF, b[i][j]*4); // 如果陣列有值,就放淡紫色
#         b[i][j]--; // 慢慢變小
#       } else fill(255); // 否則, 就放白色
#       rect( j*50, i*50, 50, 50); // 小格子 (右手j對應x座標, 左手i對應y座標, 寬,高)
#     }
#   }
# }
# void mouseDragged() {
#   int i = mouseY / 50, j = mouseX / 50; //左手i對應y座標, 右手j對應x座標
#   b[i][j] = 60; // 設成60, 倒數計時的紫色
# }
# ```

# %% [markdown]
# ![week06-3.png](data:image/png;base64,...)

# %% [markdown]
# ```cpp
# // week06-3a.cpp SOIT106_BASE_001
# #include <stdio.h>
# int main()
# {
#     int N;
#     scanf("%d", &N);
#     printf("%d %d\n", N/7, N%7);
# }
# ```

# %% [markdown]
# ```cpp
# // week06-3b.cpp SOIT106_BASE_007
# #include <stdio.h>
# int main()
# {
#     int a, b;
#     scanf("%d%d", &a, &b);
#     printf("%d\n", a/b );
# }
# ```

# %% [markdown]
# ```cpp
# // week06-3c.cpp SOIT107_Base_003
# #include <stdio.h>
# int main()
# {
#     int a, b;
#     scanf("%d%d", &a, &b);
#     printf("%d", a%b);
# }
# ```

# %% [markdown]
# ```cpp
# // week06-3d.cpp SOIT107_Base_005
# #include <stdio.h>
# int main()
# {
#     printf("Enter two numbers: ");
#     int a, b;
#     scanf("%d%d", &a, &b);
#     //printf("%d", a%b);
#     printf("The remainder is %d\n", a%b);
# }
# ```

# %% [markdown]
# ![week06-4.png](data:image/png;base64,...)

# %% [markdown]
# ```cpp
# // week06-4a.cpp SOIT107_Base_020
# #include <stdio.h>
# int main()
# {
#     int N;
#     for (int i=0; i<6; i++) {
#         scanf("%d", &N);
#         printf("%d\n", N*N*N);
#     }
# }
# ```

# %% [markdown]
# ```cpp
# // week06-4b.cpp SOIT107_Base_008
# #include <stdio.h>
# int main()
# {
#     printf("Enter the number of values to be processed: ");
#     int N;
#     scanf("%d", &N);
#     int ans = 1;
#     for (int i=0; i<N; i++){
#         printf("Enter a value: ");
#         int now;
#         scanf("%d", &now);
#         ans = ans * now;
#     }
#     printf("Product of the %d values is %d", N, ans);
# }
# ```

# %% [markdown]
# ![week06-5.png](data:image/png;base64,...)

# %% [markdown]
# ```cpp
# // week06-5a.cpp SOIT107_Base_010
# #include <stdio.h>
# int main()
# {
#     int N;
#     scanf("%d", &N);
#     if (N==1) printf("31");
#     if (N==2) printf("28");
#     if (N==3) printf("31");
#     if (N==4) printf("30");
#     if (N==5) printf("31");
#     if (N==6) printf("30");
#     if (N==7) printf("31");
#     if (N==8) printf("31");
#     if (N==9) printf("30");
#     if (N==10) printf("31");
#     if (N==11) printf("30");
#     if (N==12) printf("31");
# }
# ```

# %% [markdown]
# ```cpp
# // week06-5b.cpp SOIT107_Base_010
# #include <stdio.h>
# int main()
# {
#     int N;
#     scanf("%d", &N);
#     if (N==2) printf("28");
#     else if (N==4 || N==6 || N==9 || N==11) printf("30");
#     else printf("31");
# }
# ```

# %% [markdown]
# ![week06-6.png](data:image/png;base64,...)

# %% [markdown]
# ```cpp
# // week06-6.cpp SOIT107_Base_019
# #include <stdio.h>
# int main()
# {
#     int a, b, c;
#     scanf("%d%d%d", &a, &b, &c);
#     if (b<a) a = b;
#     if (c<a) a = c;
#     printf("%d\n", a);
# }
# ```
